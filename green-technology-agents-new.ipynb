# %%
## Sophia Hart
## Title: Green Technology Agents
### Subtitle: Research Agents does the latest research and provides a summary. It has memory capability and saves tokens.
## Google 5-Day Agentic AI Intensive Capstone Project
## Nov 2025

# %% [markdown]
# ### Session 1: Setup

# %% [markdown]
# #### 1.1 Authenticate in the Notebook
# Before running the cell below, enter GOOGLE_API_KEY in the Secrets under Add-ons.
# #### IMPORTANT: IF RUNNING DEPLOYMENT, DON'T RUN THIS CELL. GO STRAIGHT TO SESSION 4 ON DEPLOYMENT.

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "FALSE"
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}")
# Out:
# ✅ Gemini API key setup complete.

# %% [markdown]
# #### 1.2 Import ADK components

# %%
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

from google.adk.agents import LlmAgent
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.adk.memory import InMemoryMemoryService
from google.adk.tools import load_memory, preload_memory

import os
import random
import time
import vertexai
from kaggle_secrets import UserSecretsClient
from vertexai import agent_engines

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %% [markdown]
# #### 1.3 Configure retry option

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %% [markdown]
# ### Session 2: Architecture

# %% [markdown]
# ### 2.1 Multi-agent
#
# **1. research_agent**: Find most updated research findings using Google Search.
#
# **2. summary_agent**: Summary findings from Rearch Agent

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %% [markdown]
# #### 2.2 Orchestration

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %% [markdown]
# ### Session 3: Agent Memory

# %% [markdown]
# #### 3.1: Helper functions
# This helper function manages a complete conversation session, handling session creation/retrieval, query processing, and response streaming.

# %%
async def run_session(
    runner_instance: Runner, user_queries: list[str] | str, session_id: str = "default"
):
    """Helper function to run queries in a session and display responses."""
    print(f"\n### Session: {session_id}")

    # Create or retrieve session
    try:
        session = await session_service.create_session(
            app_name=APP_NAME, user_id=USER_ID, session_id=session_id
        )
    except:
        session = await session_service.get_session(
            app_name=APP_NAME, user_id=USER_ID, session_id=session_id
        )

    # Convert single query to list
    if isinstance(user_queries, str):
        user_queries = [user_queries]

    # Process each query
    for query in user_queries:
        print(f"\nUser > {query}")
        query_content = types.Content(role="user", parts=[types.Part(text=query)])

        # Stream agent response
        async for event in runner_instance.run_async(
            user_id=USER_ID, session_id=session.id, new_message=query_content
        ):
            if event.is_final_response() and event.content and event.content.parts:
                text = event.content.parts[0].text
                if text and text != "None":
                    print(f"Model: > {text}")


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %% [markdown]
# #### 3.2 Three-step memory integration process:
#
# **Initialize** → Create a MemoryService and provide it to your agent via the Runner
#
# **Ingest** → Transfer session data to memory using add_session_to_memory()
#
# **Retrieve** → Search stored memories using search_memory()

# %% [markdown]
# #### a. Initialize Memory

# %%
memory_service = (
    InMemoryMemoryService()
)  # ADK's built-in Memory Service for development and testing

# %%
# Define constants used throughout the notebook
APP_NAME = "ResearchMemoryApp"
USER_ID = "demo_user"

# Create agent
user_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="ResearchMemoryAgent",
    instruction="Answer user questions in simple words. Use load_memory tool if you need to recall past conversations.",
    tools=[AgentTool(agent=root_agent), 
           load_memory],  # Agent now has access to Memory and can search it whenever it decides to!
)

print("✅ Agent with load_memory tool created.")
# Out:
# ✅ Agent with load_memory tool created.

# %% [markdown]
# #### b. Create Runner¶
# Now provide both Session and Memory services to the Runner.
#
# Key configuration:
#
# The Runner requires both services to enable memory functionality:
#
# **session_service** → Manages conversation threads and events
#
# **memory_service** → Provides long-term knowledge storage
#
# Both services work together: Sessions capture conversations, Memory stores knowledge for retrieval across sessions.

# %%
# Create Session Service
session_service = InMemorySessionService()  # Handles conversations

# Create runner with BOTH services
runner = Runner(
    agent=user_agent,
    app_name="ResearchMemoryApp",
    session_service=session_service,
    memory_service=memory_service,  # Memory service is now available!
)

print("✅ Agent and Runner created with memory support!")
# Out:
# ✅ Agent and Runner created with memory support!

# %% [markdown]
# #### c. Create a Session

# %%
# User tells agent about their favorite color
await run_session(
    runner,
    "I'm interested in green technology, especially fusion, fission, and battery technologies. What are the latest advancements in sustainable energy?",
    "conversation-01",  # Session ID
)
# Out:
# ### Session: conversation-01
#
# User > I'm interested in green technology, especially fusion, fission, and battery technologies. What are the latest advancements in sustainable energy?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Model: > Recent breakthroughs in sustainable energy include advancements in fusion energy research, particularly in understanding plasma behavior through sophisticated modeling and international collaborations. In fission energy, China is leading the expansion with new reactor designs, and Small Modular Reactors (SMRs) are being developed for better cost-efficiency and safety. For battery technologies, there's rapid progress in areas like sodium-ion, solid-state, and graphene batteries, aiming to improve efficiency, reduce costs, and enhance safety for applications ranging from grid storage to electric vehicles.

# %% [markdown]
# Let's verify the conversation is captured in the session.

# %%
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="conversation-01"
)

# Let's see what's in the session
print("📝 Session contains:")
for event in session.events:
    # 1. Start with the default empty text
    text = "(empty)"
    
    # 2. Check if content exists
    if event.content:
        # 3. Check if 'parts' list exists AND is not empty
        if event.content.parts and len(event.content.parts) > 0:
            part = event.content.parts[0]
            
            # 4. Check if the 'text' attribute exists on the part
            if hasattr(part, 'text') and part.text:
                text = part.text[:60]
            # Handle the case where the part is a non-text type (e.g., function call, image, etc.)
            else:
                 text = f"({part.type if hasattr(part, 'type') else 'Non-Text Part'})..."

    print(f"  {event.content.role if event.content else 'None'}: {text}...")
# Out:
# 📝 Session contains:
#   user: I'm interested in green technology, especially fusion, fissi...
#   model: (Non-Text Part)......
#   user: (Non-Text Part)......
#   model: Recent breakthroughs in sustainable energy include advanceme...

# %% [markdown]
# #### d. Add Session to Memory

# %% [markdown]
# Perfect! The session contains our conversation. Now we're ready to transfer it to memory. Call add_session_to_memory() and pass the session object. This ingests the conversation into the memory store, making it available for future searches.

# %%
# This is the key method!
await memory_service.add_session_to_memory(session)

print("✅ Session added to memory!")
# Out:
# ✅ Session added to memory!

# %% [markdown]
# Test the memory.

# %%
await run_session(runner, "what area of sustainability am I interested?", "interest test")
# Out:
# ### Session: interest test
#
# User > what area of sustainability am I interested?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Model: > You are interested in green technology, specifically fusion, fission, and battery technologies.

# %% [markdown]
# ### 3.3: Now, let's add more to the conversation!
# Has to the same session-id: conversation-01

# %%
# User tells agent about other details on the interest
await run_session(
    runner,
    "I'm also interested in what companies are ahead in these green technologies. List these company names, how their technology stands out, and why the company is successful.",
    "conversation-01",  # Session ID
)
# Out:
# ### Session: conversation-01
#
# User > I'm also interested in what companies are ahead in these green technologies. List these company names, how their technology stands out, and why the company is successful.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Model: > Here are some of the companies leading in green technology sectors:
#
# **Fusion Energy:**
# *   **TAE Technologies:** Focuses on an aneutronic fusion approach using advanced beam-driven field-reversed configuration (FRC) technology. Their success is driven by significant private investment and a unique approach to achieving fusion.
# *   **Helion Energy:** Developing a pulsed non-ignition fusion approach aiming for a device that generates more electricity than it consumes. They have secured substantial funding and are backed by prominent investors.
# *   **Commonwealth Fusion Systems (CFS):** A spin-off from MIT, CFS is developing compact fusion devices using high-temperature superconducting (HTS) magnets. Their innovation in magnet technology allows for smaller, potentially more cost-effective fusion reactors. They have strong backing from major investors.
# *   **General Fusion:** Pursuing a magnetized target fusion (MTF) approach, which uses lasers or other drivers to compress a plasma. Their unique method and significant funding contribute to their progress.
# *   **Tokamak Energy:** Innovating with spherical tokamaks and HTS magnets to create more compact and efficient fusion power plants. Their focus on modular designs and advanced materials sets them apart.
#
# **Fission Energy:**
# *   **newcleo:** Developing fast-spectrum Generation IV reactors that can utilize existing nuclear waste as fuel, offering enhanced safety and sustainability. They are attracting investment through their innovative fuel cycle approach.
# *   **Kairos Power:** Focused on developing fluoride salt-cooled, high-temperature, gas-cooled reactors (Fluoride Salt-Cooled High-Temperature Reactors - FHRs) with a strong emphasis on inherent safety features.
# *   **Deep Fission:** Working on advanced fission concepts aimed at greater safety and efficiency.
# *   **BWX Technologies (BWXT):** A long-standing player in the nuclear industry, they are involved in developing advanced nuclear reactors, including SMRs, leveraging their extensive experience and existing infrastructure.
# *   **Valar Atomics:** Developing modular, inherently safe, fast-spectrum fission reactors. Their success is tied to their focus on safety and deployability.
#
# **Battery Technologies:**
# *   **Tesla:** A leader in both electric vehicles and battery storage, known for its Gigafactories, advancements in lithium-ion and LFP (lithium iron phosphate) battery technology, and vertical integration. Their success comes from innovation, scale, and brand recognition.
# *   **BYD:** A major global manufacturer of batteries and electric vehicles, excelling in LFP battery technology and vertical integration. Their cost-effectiveness and massive production capacity are key to their success.
# *   **LG Energy Solution:** A leading global battery supplier for EVs and energy storage systems, known for its reliable lithium-ion battery technology and strong partnerships with major automakers.
# *   **CATL (Contemporary Amperex Technology Co. Limited):** The world's largest battery manufacturer, supplying a vast range of battery technologies, particularly for EVs. Their scale, cost control, and continuous innovation in lithium-ion chemistries drive their success.
# *   **Panasonic:** A long-time partner of Tesla and a major supplier of lithium-ion batteries, known for its high-performance battery cells and continuous research and development.
# *   **QuantumScape:** Focused on developing next-generation solid-state batteries, which promise higher energy density and improved safety compared to current lithium-ion batteries. They have significant backing from automotive partners like Volkswagen.
# *   **Samsung SDI:** A key player in lithium-ion batteries for EVs and electronics, also investing heavily in next-generation battery technologies.
# *   **Enphase Energy:** While not a battery cell manufacturer, they are a leader in integrated renewable energy solutions, including home battery storage systems, microinverters, and energy management software. Their success lies in offering a comprehensive and reliable energy ecosystem.

# %% [markdown]
# Manually save session to memory

# %%
# Manually save the session to memory
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="conversation-01"
)

await memory_service.add_session_to_memory(session)

print("✅ Green Technology session saved to memory!")
# Out:
# ✅ Green Technology session saved to memory!

# %% [markdown]
# See what's in the memory

# %%
# Let's see what's in the memory
search_response = await memory_service.search_memory(
    app_name=APP_NAME, user_id=USER_ID, query="What is the user's interests?"
)

print("🔍 Search Results:")
print(f"  Found {len(search_response.memories)} relevant memories")
print()

for memory in search_response.memories:
    if memory.content and memory.content.parts:
        text = memory.content.parts[0].text[:80]
        print(f"  [{memory.author}]: {text}...")
# Out:
# 🔍 Search Results:
#   Found 4 relevant memories
#
#   [user]: I'm interested in green technology, especially fusion, fission, and battery tech...
#   [ResearchMemoryAgent]: Recent breakthroughs in sustainable energy include advancements in fusion energy...
#   [user]: I'm also interested in what companies are ahead in these green technologies. Lis...
#   [ResearchMemoryAgent]: Here are some of the companies leading in green technology sectors:
#
# **Fusion En...

# %% [markdown]
# ### Session 4: Deployment

# %%
import os
import random
import time
import vertexai
from kaggle_secrets import UserSecretsClient
from vertexai import agent_engines

print("✅ Imports completed successfully")
# Out:
# ✅ Imports completed successfully

# %% [markdown]
# #### a. Set up Cloud credential

# %%
# Set up Cloud Credentials in Kaggle
user_secrets = UserSecretsClient()
user_credential = user_secrets.get_gcloud_credential()
user_secrets.set_tensorflow_credential(user_credential)

print("✅ Cloud credentials configured")
# Out:
# ✅ Cloud credentials configured

# %% [markdown]
# #### b. Project-id

# %%
## Set your PROJECT_ID
PROJECT_ID = "myfirstagent-478223"  # TODO: Replace with your project ID
os.environ["GOOGLE_CLOUD_PROJECT"] = PROJECT_ID

if PROJECT_ID == "your-project-id" or not PROJECT_ID:
    raise ValueError("⚠️ Please replace 'your-project-id' with your actual Google Cloud Project ID.")

print(f"✅ Project ID set to: {PROJECT_ID}")
# Out:
# ✅ Project ID set to: myfirstagent-478223

# %% [markdown]
# #### c. Create agent directory and necessary files

# %%
## Create simple agent - all code for the agent will live in this directory
# !mkdir -p green_tech_agent

print(f"✅ Green Technology Agent directory created")
# Out:
# ✅ Green Technology Agent directory created

# %%
# %%writefile green_tech_agent/requirements.txt
#
# google-adk
# opentelemetry-instrumentation-google-genai
# Out:
# Writing green_tech_agent/requirements.txt

# %%
# %%writefile green_tech_agent/.env
#
# # https://cloud.google.com/vertex-ai/generative-ai/docs/learn/locations#global-endpoint
# GOOGLE_CLOUD_LOCATION="global"
#
# # Set to 1 to use Vertex AI, or 0 to use Google AI Studio
# GOOGLE_GENAI_USE_VERTEXAI=1
# Out:
# Writing green_tech_agent/.env

# %% [markdown]
# #### d. Create agent code
# The code below does not include agent memory. To implement agent memory for deployment, copy every cell from Session 3 (Agent Memory) above into the bottom of the cell below. Ensure the entire code is in a single cell so that it is written to the agent.py file completely.

# %%
# %%writefile green_tech_agent/agent.py
from google.adk.agents import Agent
import vertexai
import os

from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

from google.adk.agents import LlmAgent
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.adk.memory import InMemoryMemoryService
from google.adk.tools import load_memory, preload_memory

vertexai.init(
    project=os.environ["GOOGLE_CLOUD_PROJECT"],
    location=os.environ["GOOGLE_CLOUD_LOCATION"],
)

# retry
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
    Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
    1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
    2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
    3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)
# Out:
# Writing green_tech_agent/agent.py

# %% [markdown]
# #### e. Config file for resource

# %%
# %%writefile green_tech_agent/.agent_engine_config.json
# {
#     "min_instances": 0,
#     "max_instances": 1,
#     "resource_limits": {"cpu": "1", "memory": "1Gi"}
# }
# Out:
# Writing green_tech_agent/.agent_engine_config.json

# %% [markdown]
# #### f. Deployment regions

# %%
regions_list = ["europe-west1", "europe-west4", "us-east4", "us-west1"]
deployed_region = random.choice(regions_list)

print(f"✅ Selected deployment region: {deployed_region}")
# Out:
# ✅ Selected deployment region: us-west1

# %% [markdown]
# #### g. Deply the agent!

# %%
# !adk deploy agent_engine --project=$PROJECT_ID --region=$deployed_region green_tech_agent --agent_engine_config_file=green_tech_agent/.agent_engine_config.json
# Out:
# Staging all files in: /kaggle/working/green_tech_agent_tmp20251124_231729
# Copying agent source code...
# Copying agent source code complete.
# Resolving files and dependencies...
# Reading agent engine config from green_tech_agent/.agent_engine_config.json
# Reading environment variables from /kaggle/working/green_tech_agent/.env
# Ignoring GOOGLE_CLOUD_LOCATION in .env as `--region` was explicitly passed and takes precedence
# Initializing Vertex AI...
# Vertex AI initialized.
# Created green_tech_agent_tmp20251124_231729/agent_engine_app.py
# Files and dependencies resolved
# Deploying to agent engine...
# INFO:vertexai_genai.agentengines:Creating in-memory tarfile of source_packages
# INFO:vertexai_genai.agentengines:Using agent framework: google-adk
# INFO:vertexai_genai.agentengines:View progress and logs at https://console.cloud.google.com/logs/query?project=myfirstagent-478223.
# INFO:vertexai_genai.agentengines:Agent Engine created. To use it in another session:
# INFO:vertexai_genai.agentengines:agent_engine=client.agent_engines.get(name='projects/3222581548/locations/us-west1/reasoningEngines/7187903334957711360')
# ✅ Created agent engine: projects/3222581548/locations/us-west1/reasoningEngines/7187903334957711360
# Cleaning up the temp folder: green_tech_agent_tmp20251124_231729

# %% [markdown]
# #### h. Retrieve the deployed agent

# %%
# Initialize Vertex AI
vertexai.init(project=PROJECT_ID, location=deployed_region)

# Get the most recently deployed agent
agents_list = list(agent_engines.list())
if agents_list:
    remote_agent = agents_list[0]  # Get the first (most recent) agent
    client = agent_engines
    print(f"✅ Connected to deployed agent: {remote_agent.resource_name}")
else:
    print("❌ No agents found. Please deploy first.")
# Out:
# ✅ Connected to deployed agent: projects/3222581548/locations/us-west1/reasoningEngines/7187903334957711360

# %%
async for item in remote_agent.async_stream_query(
    message="What is the latest progress in green technology, especially fusion, fission, and battery technology?",
    user_id="user_42",
):
    print(item)
# Out:
# {'model_version': 'gemini-2.5-flash-lite', 'content': {'parts': [{'function_call': {'id': 'adk-44469d47-1101-4e0e-a61f-ed12cbcd00a4', 'args': {'request': 'Latest progress in green technology, including fusion, fission, and battery technology.'}, 'name': 'ResearchAgent'}}], 'role': 'model'}, 'finish_reason': 'STOP', 'usage_metadata': {'candidates_token_count': 18, 'candidates_tokens_details': [{'modality': 'TEXT', 'token_count': 18}], 'prompt_token_count': 142, 'prompt_tokens_details': [{'modality': 'TEXT', 'token_count': 142}], 'thoughts_token_count': 113, 'total_token_count': 273, 'traffic_type': 'ON_DEMAND'}, 'avg_logprobs': -0.822260856628418, 'invocation_id': 'e-e0eaa86a-1909-4f42-87cd-9f1c1329c054', 'author': 'ResearchCoordinator', 'actions': {'state_delta': {}, 'artifact_delta': {}, 'requested_auth_configs': {}, 'requested_tool_confirmations': {}}, 'long_running_tool_ids': [], 'id': '1aa1baa6-5490-4299-8ac7-0c77cf4dd4ab', 'timestamp': 1764026759.873439}
# {'content': {'parts': [{'function_response': {'id': 'adk-44469d47-1101-4e0e-a61f-ed12cbcd00a4', 'name': 'ResearchAgent', 'response': {'result': "Recent advancements in green technology showcase significant progress in fusion energy, fission power, and battery technology.\n\nIn fusion energy, the international ITER project continues its work towards achieving fusion power at a plant scale, aiming to demonstrate the technology for future fusion power plants. China has also entered the fusion race with a substantial budget, and companies worldwide are investing heavily, with Microsoft striking a deal to purchase fusion-generated electricity by 2028. The U.S. Department of Energy has released a Fusion Science and Technology Roadmap to accelerate the commercialization of fusion energy by the mid-2030s, fostering collaboration between public and private sectors. Breakthroughs in magnet technology by companies like Tokamak Energy are also paving the way for more efficient fusion reactors.\n\nRegarding fission power, there is a global ambition to triple nuclear capacity by 2050, with 23 countries committed to this goal. Nuclear energy is recognized for its low lifecycle greenhouse gas emissions and its ability to provide consistent, clean power. Innovative approaches, such as Deep Fission's concept of placing nuclear reactors deep underground, are being explored to enhance safety and efficiency.\n\nBattery technology is also seeing rapid development. New battery technologies are emerging with higher energy densities, faster charging capabilities, and longer lifespans, aiming to surpass current lithium-ion technology by 2030. Innovations include graphene batteries promising faster charging and longer lifespans, and advancements in silicon and sodium anodes, as well as solid-state electrolytes. A novel zinc-based organic polymer battery has demonstrated an exceptional lifespan, potentially lasting for millions of miles. Research is also focused on improving battery recycling processes to reduce environmental impact."}}}], 'role': 'user'}, 'invocation_id': 'e-e0eaa86a-1909-4f42-87cd-9f1c1329c054', 'author': 'ResearchCoordinator', 'actions': {'state_delta': {'research_findings': "Recent advancements in green technology showcase significant progress in fusion energy, fission power, and battery technology.\n\nIn fusion energy, the international ITER project continues its work towards achieving fusion power at a plant scale, aiming to demonstrate the technology for future fusion power plants. China has also entered the fusion race with a substantial budget, and companies worldwide are investing heavily, with Microsoft striking a deal to purchase fusion-generated electricity by 2028. The U.S. Department of Energy has released a Fusion Science and Technology Roadmap to accelerate the commercialization of fusion energy by the mid-2030s, fostering collaboration between public and private sectors. Breakthroughs in magnet technology by companies like Tokamak Energy are also paving the way for more efficient fusion reactors.\n\nRegarding fission power, there is a global ambition to triple nuclear capacity by 2050, with 23 countries committed to this goal. Nuclear energy is recognized for its low lifecycle greenhouse gas emissions and its ability to provide consistent, clean power. Innovative approaches, such as Deep Fission's concept of placing nuclear reactors deep underground, are being explored to enhance safety and efficiency.\n\nBattery technology is also seeing rapid development. New battery technologies are emerging with higher energy densities, faster charging capabilities, and longer lifespans, aiming to surpass current lithium-ion technology by 2030. Innovations include graphene batteries promising faster charging and longer lifespans, and advancements in silicon and sodium anodes, as well as solid-state electrolytes. A novel zinc-based organic polymer battery has demonstrated an exceptional lifespan, potentially lasting for millions of m ...
# {'model_version': 'gemini-2.5-flash-lite', 'content': {'parts': [{'function_call': {'id': 'adk-5f07d6e2-c1ad-431c-b832-c3a58c8fd684', 'args': {'request': 'Summarize the following text about recent advancements in green technology: "Recent advancements in green technology showcase significant progress in fusion energy, fission power, and battery technology. In fusion energy, the international ITER project continues its work towards achieving fusion power at a plant scale, aiming to demonstrate the technology for future fusion power plants. China has also entered the fusion race with a substantial budget, and companies worldwide are investing heavily, with Microsoft striking a deal to purchase fusion-generated electricity by 2028. The U.S. Department of Energy has released a Fusion Science and Technology Roadmap to accelerate the commercialization of fusion energy by the mid-2030s, fostering collaboration between public and private sectors. Breakthroughs in magnet technology by companies like Tokamak Energy are also paving the way for more efficient fusion reactors. Regarding fission power, there is a global ambition to triple nuclear capacity by 2050, with 23 countries committed to this goal. Nuclear energy is recognized for its low lifecycle greenhouse gas emissions and its ability to provide consistent, clean power. Innovative approaches, such as Deep Fission\'s concept of placing nuclear reactors deep underground, are being explored to enhance safety and efficiency. Battery technology is also seeing rapid development. New battery technologies are emerging with higher energy densities, faster charging capabilities, and longer lifespans, aiming to surpass current lithium-ion technology by 2030. Innovations include graphene batteries promising faster charging and longer lifespans, and advancements in silicon and sodium anodes, as well as solid-state electrolytes. A novel zinc-based organic polymer battery has demonstrated an exceptional lifespan, potentially lasting for millions of miles. Research is also focused on improving battery recycling processes to reduce environmental impact."'}, 'name': 'SummarizerAgent'}}], 'role': 'model'}, 'finish_reason': 'STOP', 'usage_metadata': {'candidates_token_count': 354, 'candidates_tokens_details': [{'modality': 'TEXT', 'token_count': 354}], 'prompt_token_count': 503, 'prompt_tokens_details': [{'modality': 'TEXT', 'token_count': 503}], 'total_token_count': 857, 'traffic_type': 'ON_DEMAND'}, 'avg_logprobs': -0.015263861855544613, 'invocation_id': 'e-e0eaa86a-1909-4f42-87cd-9f1c1329c054', 'author': 'ResearchCoordinator', 'actions': {'state_delta': {}, 'artifact_delta': {}, 'requested_auth_configs': {}, 'requested_tool_confirmations': {}}, 'long_running_tool_ids': [], 'id': 'f1b7bd76-48ba-46e9-8a9b-341659ec6af6', 'timestamp': 1764026763.808096}
# {'content': {'parts': [{'function_response': {'id': 'adk-5f07d6e2-c1ad-431c-b832-c3a58c8fd684', 'name': 'SummarizerAgent', 'response': {'result': "Here's a summary of the provided text:\n\n*   **Fusion Energy:** Significant global investment and research are underway, including the ITER project, national roadmaps, and private sector involvement aiming for commercialization by the mid-2030s.\n*   **Fission Power:** There's a global commitment to triple nuclear capacity by 2050, recognizing its clean, consistent power generation, with innovative safety and efficiency concepts being explored.\n*   **Battery Technology:** Rapid advancements are leading to new battery types (e.g., graphene, solid-state, zinc-based) with improved energy density, charging speed, and lifespan, aiming to exceed current lithium-ion technology by 2030, alongside efforts in recycling."}}}], 'role': 'user'}, 'invocation_id': 'e-e0eaa86a-1909-4f42-87cd-9f1c1329c054', 'author': 'ResearchCoordinator', 'actions': {'state_delta': {'final_summary': "Here's a summary of the provided text:\n\n*   **Fusion Energy:** Significant global investment and research are underway, including the ITER project, national roadmaps, and private sector involvement aiming for commercialization by the mid-2030s.\n*   **Fission Power:** There's a global commitment to triple nuclear capacity by 2050, recognizing its clean, consistent power generation, with innovative safety and efficiency concepts being explored.\n*   **Battery Technology:** Rapid advancements are leading to new battery types (e.g., graphene, solid-state, zinc-based) with improved energy density, charging speed, and lifespan, aiming to exceed current lithium-ion technology by 2030, alongside efforts in recycling."}, 'artifact_delta': {}, 'requested_auth_configs': {}, 'requested_tool_confirmations': {}}, 'id': 'c68e6c1a-beb1-44a0-a5cb-260b12772e3d', 'timestamp': 1764026765.877983}
# {'model_version': 'gemini-2.5-flash-lite', 'content': {'parts': [{'text': "Here's a summary of the latest progress in green technology:\n\n*   **Fusion Energy:** There's substantial global investment and research, with major projects like ITER, national roadmaps, and private companies aiming for commercialization by the mid-2030s.\n*   **Fission Power:** Nations are committed to tripling nuclear capacity by 2050, acknowledging its role in providing consistent, clean energy, and new approaches to enhance safety and efficiency are being developed.\n*   **Battery Technology:** Innovations in battery technology are rapidly emerging, with new types of batteries offering higher energy density, faster charging, and longer lifespans, with the goal of surpassing current lithium-ion capabilities by 2030. Research is also focusing on improving battery recycling."}], 'role': 'model'}, 'finish_reason': 'STOP', 'usage_metadata': {'candidates_token_count': 161, 'candidates_tokens_details': [{'modality': 'TEXT', 'token_count': 161}], 'prompt_token_count': 1016, 'prompt_tokens_details': [{'modality': 'TEXT', 'token_count': 1016}], 'total_token_count': 1177, 'traffic_type': 'ON_DEMAND'}, 'avg_logprobs': -0.18530656091915154, 'invocation_id': 'e-e0eaa86a-1909-4f42-87cd-9f1c1329c054', 'author': 'ResearchCoordinator', 'actions': {'state_delta': {}, 'artifact_delta': {}, 'requested_auth_configs': {}, 'requested_tool_confirmations': {}}, 'id': '0d517f91-39b8-4393-89b5-f762edd8061b', 'timestamp': 1764026765.979986}

# %% [markdown]
# ### IMPORTANT: Delete the deployed agent
# To not continue to incur cost.

# %%
agent_engines.delete(resource_name=remote_agent.resource_name, force=True)

print("✅ Agent successfully deleted")
# Out:
# INFO:vertexai.agent_engines:Deleting AgentEngine resource: projects/3222581548/locations/us-west1/reasoningEngines/7187903334957711360
# INFO:vertexai.agent_engines:Delete AgentEngine backing LRO: projects/3222581548/locations/us-west1/operations/5929188195915792384
# INFO:vertexai.agent_engines:AgentEngine resource deleted: projects/3222581548/locations/us-west1/reasoningEngines/7187903334957711360
# ✅ Agent successfully deleted
